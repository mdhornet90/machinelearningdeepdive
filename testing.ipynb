# %%
# %pylab inline
import matplotlib.pyplot as plt
import dataload
import tools
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
loaded = dataload.DataLoad()
random_image = tools.get_random_image_data(loaded)
plt.imshow(tools.get_random_image_data(loaded), interpolation="bicubic")
